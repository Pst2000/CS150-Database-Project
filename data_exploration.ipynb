# %% [markdown]
# **A data science experiment using data from the KDD 2010 Educational Data Mining Challenge**
#
# The aim of this IPython Notebook is to give you a sense of the dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import random

# %%
# Get the data:
train_filepath = 'data/train.csv'
traindata = pd.read_table(train_filepath)

# %%
traindata.columns
# Out:
# Index(['Row', 'Anon Student Id', 'Problem Hierarchy', 'Problem Name',
#        'Problem View', 'Step Name', 'Step Start Time',
#        'First Transaction Time', 'Correct Transaction Time', 'Step End Time',
#        'Step Duration (sec)', 'Correct Step Duration (sec)',
#        'Error Step Duration (sec)', 'Correct First Attempt', 'Incorrects',
#        'Hints', 'Corrects', 'KC(Default)', 'Opportunity(Default)'],
#       dtype='object')

# %%
# Inspect some of the training data
traindata.head()
# Out:
#     Row Anon Student Id                Problem Hierarchy Problem Name  \
# 0  9938      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
# 1  9939      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
# 2  9940      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
# 3  9941      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
# 4  9942      52vEY7f17k  Unit CTA1_13, Section CTA1_13-1       PROP04
#
#    Problem View Step Name        Step Start Time First Transaction Time  \
# 0             1      R1C1  2005-09-09 12:23:34.0  2005-09-09 12:24:07.0
# 1             1      R1C2  2005-09-09 12:24:07.0  2005-09-09 12:24:22.0
# 2             1      R3C1  2005-09-09 12:24:22.0  2005-09-09 12:25:16.0
# 3             1      R3C2  2005-09-09 12:25:40.0  2005-09-09 12:25:51.0
# 4             1      R4C1  2005-09-09 12:27:24.0  2005-09-09 12:27:30.0
#
#   Correct Transaction Time          Step End Time  Step Duration (sec)  \
# 0    2005-09-09 12:24:07.0  2005-09-09 12:24:07.0                 33.0
# 1    2005-09-09 12:24:22.0  2005-09-09 12:24:22.0                 15.0
# 2    2005-09-09 12:25:40.0  2005-09-09 12:25:40.0                 78.0
# 3    2005-09-09 12:27:24.0  2005-09-09 12:27:24.0                104.0
# 4    2005-09-09 12:27:30.0  2005-09-09 12:27:30.0                  6.0
#
#    Correct Step Duration (sec)  Error Step Duration (sec)  \
# 0                         33.0                        NaN
# 1                         15.0                        NaN
# 2                          NaN                       78.0
# 3                          NaN                      104.0
# 4                          6.0                        NaN
#
#    Correct First Attempt  Incorrects  Hints  Corrects  \
# 0                      1           0      0         1
# 1                      1           0      0         1
# 2                      0           2      0         1
# 3                      0           4      9         1
# 4                      1           0      0         1
#
#                                          KC(Default) Opportunity(Default)
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2                                    Define Variable                    1
# 3  Using small numbers~~Write expression, positiv...              1~~1~~1
# 4                                   Entering a given                    1

# %%
traindata['Step Name']
# Out:
# 0         R1C1
# 1         R1C2
# 2         R3C1
# 3         R3C2
# 4         R4C1
#           ...
# 232739    R5C1
# 232740    R1C2
# 232741    R2C2
# 232742    R3C2
# 232743    R6C2
# Name: Step Name, Length: 232744, dtype: object

# %% [markdown]
# Let's begin asking some basic questions of the data
#
# ### How many students are interacting with the system?

# %%
# Take the column of anonimized student IDs and count the number of unique entries
print('Number of students: ', len(np.unique(traindata['Anon Student Id'])))
# Out:
# Number of students:  174

# %% [markdown]
# ### How long does it take a student to solve any problem step on average?

# %%
csd = traindata['Correct Step Duration (sec)']
csd.describe()
# Out:
# count    181599.000000
# mean         17.924024
# std          35.179534
# min           0.000000
# 25%           5.000000
# 50%           8.000000
# 75%          17.000000
# max        1067.000000
# Name: Correct Step Duration (sec), dtype: float64

# %% [markdown]
# So ignoring all the students that did not solve a problem step correctly, the average duraction for any problem step was about 18 seconds.
#
# Let's histogram this data to see the distribution.

# %%
# %matplotlib inline
hist = plt.hist(np.array(csd.dropna()),bins=100,density=True,log=False,range=(0,100))
plt.xlabel('Time to correct answer (sec)')
plt.ylabel('Fraction')
plt.show()

# %%
counts, bins = hist[0], hist[1]
cdf = np.cumsum(counts)
plt.plot(bins[1::], cdf)
plt.xlabel('Time to correct answer (sec)')
plt.ylabel('Cumulative fraction')
plt.axis((0,100,0,1.0))
plt.show()

# %% [markdown]
# The histogram shows visually what mere statistics hints at. The distribution of students is heavily weighted towards those who are solving problems in under 20 seconds. The cumulative distribution function (CDF) shows that roughly 80% of successful students solve the problem within 20 seconds. After 40 seconds, 90% of successful students have finished the problem. Almost no students take longer than 80 seconds.

# %% [markdown]
# ### Completion time by problem
#
# OK, let's ask a slightly harder question: how are students doing problem by problem? The answer will take several parts.
#
# First, let's get the number of unique problems

# %%
# The unique identifier for each problem is the 'Problem Name'
problems = traindata['Problem Name']

# %%
# Get just the uniques
problems = np.unique(problems)
print('Number of unique problems: ', len(problems))
# Out:
# Number of unique problems:  1021

# %% [markdown]
# Then, let's compute which problems need the largest time on average.

# %%
pmedian_times = {}
for p in problems:
    pmedian_times[p] = traindata[traindata['Problem Name'] == p]['Correct Step Duration (sec)'].median()

# %%
import operator

# %%
sorted_times = sorted(pmedian_times.items(), key=operator.itemgetter(1), reverse=True)

# %%
print("The hardest top-5 problem and its average correct duration (sec).")
print(sorted_times[:5])

print("The earliest top-5 problem and its average correct duration (sec).")
print(sorted_times[len(sorted_times)-5:])
# Out:
# The hardest top-5 problem and its average correct duration (sec).
# [('JAN13C', 65.0), ('TRANSFORMN022', 32.0), ('EG-FACTOR45', 30.0), ('BH1T33B', 25.0), ('EG-FACTOR47', 23.0)]
# The earliest top-5 problem and its average correct duration (sec).
# [('TRANSFORMN013', 1.25), ('TRANSFORMN014', 1.25), ('TRANSFORMG042', 1.0), ('TRANSFORMN004', 1.0), ('TRANSFORMN005', 1.0)]

# %% [markdown]
# Statistical results of problem difficulty

# %%
hist = plt.hist(np.array(list(pmedian_times.values())),bins=15,density=True,log=False,range=(0,25))
plt.xlabel('Time to correct answer (sec)')
plt.ylabel('Number')
plt.show()
# Out:
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# If we take the time to correct answer as the difficulty of a problem, the histogram shows visually the difficulties of all the problems.

# %% [markdown]
# ### Conclusion
# There are many other interesting characteristic in this dataset.
# Like,
# * After some practices, students may become better at solving problems.
# * Same problem step for different students may request different knowledge components. Or for some problems, there is only one correct knowledge components
#
# These may be some things you need to take consider into for the feature engineering part. We leave them for you to explore deeper.

# %% [markdown]
# ## Have a look at test data

# %%
test_filepath = 'data/test.csv'
testdata = pd.read_table(test_filepath)

# %%
testdata
# Out:
#           Row Anon Student Id  \
# 0       10039      52vEY7f17k
# 1       10482      52vEY7f17k
# 2       11024      52vEY7f17k
# 3       11476      52vEY7f17k
# 4       11948      52vEY7f17k
# ...       ...             ...
# 1135  1075314      C0qLCIhI0O
# 1136  1076841      e95f4UtF4I
# 1137  1076862      e95f4UtF4I
# 1138  1076891      e95f4UtF4I
# 1139  1078861      JP20cryBg8
#
#                                       Problem Hierarchy    Problem Name  \
# 0                       Unit CTA1_13, Section CTA1_13-1          PROP01
# 1                       Unit CTA1_06, Section CTA1_06-3           FOR05
# 2                           Unit ES_03, Section ES_03-6            EG52
# 3                       Unit CTA1_08, Section CTA1_08-3          REAL10
# 4                          Unit ES_04, Section ES_04-12            EG58
# ...                                                 ...             ...
# 1135                    Unit CTA1_24, Section CTA1_24-1          L5FB05
# 1136  Unit EXPT-PRODUCT-SIMP-A_ES, Section EXPT-PROD...  EG-EPS01-FIXED
# 1137  Unit EXPT-QUOTIENT-SIMP-A_ES, Section EXPT-QUO...        EG-EQS08
# 1138                    Unit CTA1_24, Section CTA1_24-1       PERCENT07
# 1139                    Unit CTA1_24, Section CTA1_24-1           NOV05
#
#       Problem View        Step Name  Step Start Time  First Transaction Time  \
# 0                1     2/300*X = 10              NaN                     NaN
# 1                1           xScale              NaN                     NaN
# 2                1  2.9 = -2x+3.7+x              NaN                     NaN
# 3                1           yScale              NaN                     NaN
# 4                7              xR2              NaN                     NaN
# ...            ...              ...              ...                     ...
# 1135             1             R4C2              NaN                     NaN
# 1136             1      FinalAnswer              NaN                     NaN
# 1137             1              2/1              NaN                     NaN
# 1138             1             R6C2              NaN                     NaN
# 1139             1             R7C1              NaN                     NaN
#
#       Correct Transaction Time  Step End Time  Step Duration (sec)  \
# 0                          NaN            NaN                  NaN
# 1                          NaN            NaN                  NaN
# 2                          NaN            NaN                  NaN
# 3                          NaN            NaN                  NaN
# 4                          NaN            NaN                  NaN
# ...                        ...            ...                  ...
# 1135                       NaN            NaN                  NaN
# 1136                       NaN            NaN                  NaN
# 1137                       NaN            NaN                  NaN
# 1138                       NaN            NaN                  NaN
# 1139                       NaN            NaN                  NaN
#
#       Correct Step Duration (sec)  Error Step Duration (sec)  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# ...                           ...                        ...
# 1135                          NaN                        NaN
# 1136                          NaN                        NaN
# 1137                          NaN                        NaN
# 1138                          NaN                        NaN
# 1139                          NaN                        NaN
#
#       Correct First Attempt  Incorrects  Hints  Corrects  \
# 0                       NaN         NaN    NaN       NaN
# 1                       NaN         NaN    NaN       NaN
# 2                       NaN         NaN    NaN       NaN
# 3                       NaN         NaN    NaN       NaN
# 4                       NaN         NaN    NaN       NaN
# ...                     ...         ...    ...       ...
# 1135                    1.0         NaN    NaN       NaN
# 1136                    1.0         NaN    NaN       NaN
# 1137                    1.0         NaN    NaN       NaN
# 1138                    1.0         NaN    NaN       NaN
# 1139                    0.0         NaN    NaN       NaN
#
#                                        KC(Default) Opportunity(Default)
# 0                                              NaN                  NaN
# 1                          Changing axis intervals                   28
# 2     [SkillRule: Consolidate vars, no coeff; CLT]                   27
# 3                          Changing axis intervals                   65
# 4                                              NaN                  NaN
# ...                                            ...                  ...
# 1135                              Entering a given                    1
# 1136                               perform-mult-sp                   11
# 1137                                           NaN                  NaN
# 1138                              Entering a given                    6
# 1139      Entering a given~~Convert unit, standard                23~~2
#
# [1140 rows x 19 columns]

# %%
# Take the column of anonimized student IDs and count the number of unique entries
print('Number of students: ', np.sum(testdata['Correct First Attempt']))
# Out:
# Number of students:  540.0

# %%
_sum_1 = 0
for i, row in testdata.iterrows():
    if row['Correct First Attempt'] == 0:
        print(row)
# print(_sum_1)
# Out:
# Row                                                                        21616
# Anon Student Id                                                       8o0mJnIpFH
# Problem Hierarchy                                Unit CTA1_06, Section CTA1_06-3
# Problem Name                                                               JAN05
# Problem View                                                                   2
# Step Name                                                                   R5C1
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                    Using simple numbers~~Using large numbers~~Fin...
# Opportunity(Default)                                                  24~~15~~18
# Name: 14, dtype: object
# Row                                                                        23277
# Anon Student Id                                                       8o0mJnIpFH
# Problem Hierarchy                                Unit CTA1_10, Section CTA1_10-5
# Problem Name                                                         DISTFB08_SP
# Problem View                                                                   1
# Step Name                                                                   R3C2
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                    Using simple numbers~~Write expression, positi...
# Opportunity(Default)                                                  78~~45~~56
# Name: 18, dtype: object
# Row                                                                        23522
# Anon Student Id                                                       8o0mJnIpFH
# Problem Hierarchy                                    Unit ES_07, Section ES_07-4
# Problem Name                                                              LIT63A
# Problem View                                                                   1
# Step Name                                                      n*t-h*r = c*j+z*n
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                    [SkillRule: Remove constant; {ax+b=c, positive...
# Opportunity(Default)                                                         228
# Name: 19, dtype: object
# Row                                                                        23621
# Anon Student Id                                                       8o0mJnIpFH
# Problem Hierarchy                                Unit CTA1_12, Section CTA1_12-2
# Problem Name                                                               SYS03
# Problem View                                                                   1
# Step Name                                                                   R3C3
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                    Using simple numbers~~Using small numbers~~Wri...
# Opportunity(Default)                                                 94~~104~~55
# Name: 20, dtype: object
# Row                                                                        36252
# Anon Student Id                                                       g209g5Vve6
# Problem Hierarchy                                   Unit ES_04, Section ES_04-14
# Problem Name                                                              LIT23A
# Problem View                                                                   1
# Step Name                                                       (n*j+56)/n = r/n
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                    [SkillRule: Multiply/Divide; [Typein Skill: {R...
# Opportunity(Default)                                                          28
# Name: 22, dtype: object
# Row                                                                        38196
# Anon Student Id                                                       g209g5Vve6
# Problem Hierarchy                                   Unit ES_05, Section ES_05-11
# Problem Name                                                               LIT87
# Problem View                                                                   1
# Step Name                                                            12y = 1-a*x
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                    [SkillRule: Remove coefficient; {ax+b=c, divid...
# Opportunity(Default)                                                         279
# Name: 26, dtype: object
# Row                                                                        39522
# Anon Student Id                                                       g209g5Vve6
# Problem Hierarchy              Unit QUAD-ADD-AREA-ALG1, Section QUAD-ADD-AREA...
# Problem Name                                                       NEWSQUARE2TRE
# Problem View                                                                   1
# Step Name                                                                   R4C2
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                    Using simple numbers~~Using small numbers~~Fin...
# Opportunity(Default)                                            254~~204~~24~~45
# Name: 30, dtype: object
# Row                                                                        40437
# Anon Student Id                                                       g209g5Vve6
# Problem Hierarchy              Unit QUAD-VERTICAL-MOTION, Section QUAD-VERTIC...
# Problem Name                                                         NEWQUAD5TRE
# Problem View                                                                   1
# Step Name                                                                   R7C1
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                                     Entering a computed linear value
# Opportunity(Default)                                                          80
# Name: 33, dtype: object
# Row                                                               99331
# Anon Student Id                                              879eYkR2Wu
# Problem Hierarchy                       Unit CTA1_20, Section CTA1_20-2
# Problem Name                                                    1PTFB17
# Problem View                                                          1
# Step Name                                                          R4C1
# Step Start Time                                                     NaN
# First Transaction Time                                              NaN
# Correct Transaction Time                                            NaN
# Step End Time                                                       NaN
# Step Duration (sec)                                                 NaN
# Correct Step Duration (sec)                                         NaN
# Error Step Duration (sec)                                           NaN
# Correct First Attempt                                                 0
# Incorrects                                                          NaN
# Hints                                                               NaN
# Corrects                                                            NaN
# KC(Default)                    Entering a given~~Convert unit, standard
# Opportunity(Default)                                            230~~14
# Name: 100, dtype: object
# Row                                                      99493
# Anon Student Id                                     879eYkR2Wu
# Problem Hierarchy              Unit CTA1_21, Section CTA1_21-3
# Problem Name                                             JAN08
# Problem View                                                 1
# Step Name                                                 yMax
# Step Start Time                                            NaN
# First Transaction Time                                     NaN
# Correct Transaction Time                                   NaN
# Step End Time                                              NaN
# Step Duration (sec)                                        NaN
# Correct Step Duration (sec)                                NaN
# Error Step Duration (sec)                                  NaN
# Correct First Attempt                                        0
# Incorrects                                                 NaN
# Hints                                                      NaN
# Corrects                                                   NaN
# KC(Default)                               Changing axis bounds
# Opportunity(Default)                                        67
# Name: 101, dtype: object
# Row                                                                        99934
# Anon Student Id                                                       879eYkR2Wu
# Problem Hierarchy                                Unit CTA1_24, Section CTA1_24-1
# Problem Name                                                           PERCENT07
# Problem View                                                                   1
# Step Name                                                                   R7C2
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                    Find Y, Simple~~Using small numbers~~Using dif...
# Opportunity(Default)                                                  4~~156~~93
# Name: 104, dtype: object
# Row                                                     160979
# Anon Student Id                                     z9svx3mA4s
# Problem Hierarchy              Unit CTA1_08, Section CTA1_08-3
# Problem Name                                            BH1T07
# Problem View                                                 1
# Step Name                                    Formula 1 Coeff 1
# Step Start Time                                            NaN
# First Transaction Time                                     NaN
# Correct Transaction Time                                   NaN
# Step End Time                                              NaN
# Step Duration (sec)                                        NaN
# Correct Step Duration (sec)                                NaN
# Error Step Duration (sec)                                  NaN
# Correct First Attempt                                        0
# Incorrects                                                 NaN
# Hints                                                      NaN
# Corrects                                                   NaN
# KC(Default)                                  Setting the slope
# Opportunity(Default)                                        13
# Name: 149, dtype: object
# Row                                                                       162608
# Anon Student Id                                                       z9svx3mA4s
# Problem Hierarchy                                Unit CTA1_14, Section CTA1_14-4
# Problem Name                                                        IPCTURDUCKEN
# Problem View                                                                   1
# Step Name                                                                   R6C1
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                    Using small numbers~~Find X, negative slope~~U...
# Opportunity(Default)                                                274~~44~~153
# Name: 155, dtype: object
# Row                                                                       163412
# Anon Student Id                                                       z9svx3mA4s
# Problem Hierarchy              Unit QUADRATICS-FACTORING_ES, Section QUADRATI...
# Problem Name                                                         EG-FACTOR24
# Problem View                                                                   1
# Step Name                                                             c-factor-2
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                                                                  NaN
# Opportunity(Default)                                                         NaN
# Name: 159, dtype: object
# Row                                                                       215764
# Anon Student Id                                                       t0fI2c7EMH
# Problem Hierarchy                                   Unit ES_02, Section ES_02-10
# Problem Name                                                                EG44
# Problem View                                                                   2
# Step Name                                                             1x = 2/x*x
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                    [SkillRule: Multiply/Divide; [Typein Skill: {R...
# Opportunity(Default)                                                          11
# Name: 184, dtype: object
# Row                                                                       216136
# Anon Student Id                                                       t0fI2c7EMH
# Problem Hierarchy              Unit QUAD-ADD-AREA-ALG1, Section QUAD-ADD-AREA...
# Problem Name                                                       NEWSQUARE1TRE
# Problem View                                                                   1
# Step Name                                                                   R8C2
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                                     Entering a computed linear value
# Opportunity(Default)                                                           7
# Name: 187, dtype: object
# Row                                                                       231825
# Anon Student Id                                                       c3Ee3W8hyq
# Problem Hierarchy                                Unit CTA1_01, Section CTA1_01-3
# Problem Name                                                             REAL20A
# Problem View                                                                   1
# Step Name                                                                   R4C2
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                    Using simple numbers~~Using large numbers~~Fin...
# Opportunity(Default)                                                   40~~18~~5
# Name: 194, dtype: object
# Row                                                 232428
# Anon Student Id                                 c3Ee3W8hyq
# Problem Hierarchy              Unit ES_01, Section ES_01-8
# Problem Name                                          EG24
# Problem View                                             1
# Step Name                                     1/7 = -7x/-7
# Step Start Time                                        NaN
# First Transaction Time                                 NaN
# Correct Transaction Time                               NaN
# Step End Time                                          NaN
# Step Duration (sec)                                    NaN
# Correct Step Duration (sec)                            NaN
# Error Step Duration (sec)                              NaN
# Correct First Attempt                                    0
# Incorrects                                             NaN
# Hints                                                  NaN
# Corrects                                               NaN
# KC(Default)                                            NaN
# Opportunity(Default)                                   NaN
# Name: 196, dtype: object
# Row                                                                       233204
# Anon Student Id                                                       c3Ee3W8hyq
# Problem Hierarchy                                Unit CTA1_13, Section CTA1_13-1
# Problem Name                                                              PROP02
# Problem View                                                                   1
# Step Name                                                                   R5C1
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                    Using small numbers~~Find X, Simple~~Using dif...
# Opportunity(Default)                                                 143~~30~~76
# Name: 199, dtype: object
# Row                                                     234487
# Anon Student Id                                     c3Ee3W8hyq
# Problem Hierarchy              Unit CTA1_08, Section CTA1_08-2
# Problem Name                                             FEB02
# Problem View                                                 1
# Step Name                                    Formula 1 Coeff 1
# Step Start Time                                            NaN
# First Transaction Time                                     NaN
# Correct Transaction Time                                   NaN
# Step End Time                                              NaN
# Step Duration (sec)                                        NaN
# Correct Step Duration (sec)                                NaN
# Error Step Duration (sec)                                  NaN
# Correct First Attempt                                        0
# Incorrects                                                 NaN
# Hints                                                      NaN
# Corrects                                                   NaN
# KC(Default)                                  Setting the slope
# Opportunity(Default)                                        12
# Name: 202, dtype: object
# Row                                                                       235088
# Anon Student Id                                                       c3Ee3W8hyq
# Problem Hierarchy                                   Unit ES_04, Section ES_04-15
# Problem Name                                                               LIT55
# Problem View                                                                   1
# Step Name                                                        (y-3) = m*(x-7)
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                    [SkillRule: Remove coefficient; {ax+b=c, divid...
# Opportunity(Default)                                                     318~~13
# Name: 203, dtype: object
# Row                                                                       235536
# Anon Student Id                                                       c3Ee3W8hyq
# Problem Hierarchy                                    Unit ES_07, Section ES_07-4
# Problem Name                                                              LIT68A
# Problem View                                                                   1
# Step Name                                                         6h = c*g+8z+2j
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                    [SkillRule: Remove coefficient; {ax+b=c, divid...
# Opportunity(Default)                                                         359
# Name: 205, dtype: object
# Row                                                              243002
# Anon Student Id                                              h0UbH181l8
# Problem Hierarchy                          Unit ES_02, Section ES_02-10
# Problem Name                                                       EG44
# Problem View                                                          1
# Step Name                                                   FinalAnswer
# Step Start Time                                                     NaN
# First Transaction Time                                              NaN
# Correct Transaction Time                                            NaN
# Step End Time                                                       NaN
# Step Duration (sec)                                                 NaN
# Correct Step Duration (sec)                                         NaN
# Error Step Duration (sec)                                           NaN
# Correct First Attempt                                                 0
# Incorrects                                                          NaN
# Hints                                                               NaN
# Corrects                                                            NaN
# KC(Default)                    simplify-fractions-sp~~perform-mult-r-sp
# Opportunity(Default)                                               1~~3
# Name: 211, dtype: object
# Row                                                     243549
# Anon Student Id                                     h0UbH181l8
# Problem Hierarchy              Unit CTA1_06, Section CTA1_06-4
# Problem Name                                            BH1T48
# Problem View                                                 1
# Step Name                                                 R4C2
# Step Start Time                                            NaN
# First Transaction Time                                     NaN
# Correct Transaction Time                                   NaN
# Step End Time                                              NaN
# Step Duration (sec)                                        NaN
# Correct Step Duration (sec)                                NaN
# Error Step Duration (sec)                                  NaN
# Correct First Attempt                                        0
# Incorrects                                                 NaN
# Hints                                                      NaN
# Corrects                                                   NaN
# KC(Default)                                   Entering a given
# Opportunity(Default)                                       296
# Name: 213, dtype: object
# Row                                                                       244253
# Anon Student Id                                                       h0UbH181l8
# Problem Hierarchy                                    Unit ES_03, Section ES_03-6
# Problem Name                                                                EG51
# Problem View                                                                   2
# Step Name                                              -0.07352941(-1.6-7.5) = y
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                    [SkillRule: Select Eliminate Parens; {CLT nest...
# Opportunity(Default)                                                          54
# Name: 214, dtype: object
# Row                                                                       249093
# Anon Student Id                                                       h0UbH181l8
# Problem Hierarchy              Unit EXPT-QUOTIENT-SIMP-A_ES, Section EXPT-QUO...
# Problem Name                                                            EG-EQS08
# Problem View                                                                   2
# Step Name                                                               1.333x^0
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                                                                  NaN
# Opportunity(Default)                                                         NaN
# Name: 231, dtype: object
# Row                                                                       283843
# Anon Student Id                                                       tlJn3I40bf
# Problem Hierarchy                                Unit CTA1_01, Section CTA1_01-4
# Problem Name                                                             L1FB12B
# Problem View                                                                   1
# Step Name                                                                   R3C2
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                    Using simple numbers~~Using small numbers~~Wri...
# Opportunity(Default)                                                  72~~32~~19
# Name: 232, dtype: object
# Row                                                                       308432
# Anon Student Id                                                       y5009rpZ12
# Problem Hierarchy                                Unit CTA1_08, Section CTA1_08-2
# Problem Name                                                              REAL31
# Problem View                                                                   1
# Step Name                                                                   R3C2
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                    Using simple numbers~~Using small numbers~~Wri...
# Opportunity(Default)                                                191~~195~~72
# Name: 255, dtype: object
# Row                                                                       311509
# Anon Student Id                                                       y5009rpZ12
# Problem Hierarchy              Unit QUADRATICS-FACTORING_ES, Section QUADRATI...
# Problem Name                                                         EG-FACTOR01
# Problem View                                                                   2
# Step Name                                                              x^2+7x+10
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                                                                  NaN
# Opportunity(Default)                                                         NaN
# Name: 265, dtype: object
# Row                                                     314108
# Anon Student Id                                     yB480DNZ70
# Problem Hierarchy              Unit CTA1_02, Section CTA1_02-4
# Problem Name                                           L2FB14C
# Problem View                                                 1
# Step Name                                                 yMax
# Step Start Time                                            NaN
# First Transaction Time                                     NaN
# Correct Transaction Time                                   NaN
# Step End Time                                              NaN
# Step Duration (sec)                                        NaN
# Correct Step Duration (sec)                                NaN
# Error Step Duration (sec)                                  NaN
# Correct First Attempt                                        0
# Incorrects                                                 NaN
# Hints                                                      NaN
# Corrects                                                   NaN
# KC(Default)                               Changing axis bounds
# Opportunity(Default)                                        37
# Name: 276, dtype: object
# Row                                                                       314337
# Anon Student Id                                                       yB480DNZ70
# Problem Hierarchy                                    Unit ES_01, Section ES_01-9
# Problem Name                                                                EG25
# Problem View                                                                   2
# Step Name                                                           -3*6 = y/6*6
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                    [SkillRule: Multiply/Divide; [Typein Skill: {R...
# Opportunity(Default)                                                           2
# Name: 277, dtype: object
# Row                                                 314799
# Anon Student Id                                 yB480DNZ70
# Problem Hierarchy              Unit ES_02, Section ES_02-5
# Problem Name                                          EG40
# Problem View                                            19
# Step Name                                       2/3 = 9y/9
# Step Start Time                                        NaN
# First Transaction Time                                 NaN
# Correct Transaction Time                               NaN
# Step End Time                                          NaN
# Step Duration (sec)                                    NaN
# Correct Step Duration (sec)                            NaN
# Error Step Duration (sec)                              NaN
# Correct First Attempt                                    0
# Incorrects                                             NaN
# Hints                                                  NaN
# Corrects                                               NaN
# KC(Default)                                            NaN
# Opportunity(Default)                                   NaN
# Name: 279, dtype: object
# Row                                                     315747
# Anon Student Id                                     yB480DNZ70
# Problem Hierarchy              Unit CTA1_06, Section CTA1_06-4
# Problem Name                                            BH1T51
# Problem View                                                 1
# Step Name                                                 xMin
# Step Start Time                                            NaN
# First Transaction Time                                     NaN
# Correct Transaction Time                                   NaN
# Step End Time                                              NaN
# Step Duration (sec)                                        NaN
# Correct Step Duration (sec)                                NaN
# Error Step Duration (sec)                                  NaN
# ...
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                    Using small numbers~~Find Y, positive slope~~U...
# Opportunity(Default)                                                  63~~27~~13
# Name: 1092, dtype: object
# Row                                                                      1053712
# Anon Student Id                                                       wu58ARZBA2
# Problem Hierarchy                                Unit CTA1_01, Section CTA1_01-4
# Problem Name                                                             L1FB12C
# Problem View                                                                   1
# Step Name                                                                   R3C2
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                    Using simple numbers~~Using small numbers~~Wri...
# Opportunity(Default)                                                    19~~9~~3
# Name: 1093, dtype: object
# Row                                                    1054059
# Anon Student Id                                     yA79w15tnU
# Problem Hierarchy              Unit CTA1_01, Section CTA1_01-2
# Problem Name                                            RXMX1C
# Problem View                                                 1
# Step Name                                                 R3C1
# Step Start Time                                            NaN
# First Transaction Time                                     NaN
# Correct Transaction Time                                   NaN
# Step End Time                                              NaN
# Step Duration (sec)                                        NaN
# Correct Step Duration (sec)                                NaN
# Error Step Duration (sec)                                  NaN
# Correct First Attempt                                        0
# Incorrects                                                 NaN
# Hints                                                      NaN
# Corrects                                                   NaN
# KC(Default)                                    Define Variable
# Opportunity(Default)                                         4
# Name: 1097, dtype: object
# Row                                                    1055187
# Anon Student Id                                     5ZR29q8c56
# Problem Hierarchy              Unit CTA1_06, Section CTA1_06-5
# Problem Name                                            FBSMR3
# Problem View                                                 1
# Step Name                                                 R4C1
# Step Start Time                                            NaN
# First Transaction Time                                     NaN
# Correct Transaction Time                                   NaN
# Step End Time                                              NaN
# Step Duration (sec)                                        NaN
# Correct Step Duration (sec)                                NaN
# Error Step Duration (sec)                                  NaN
# Correct First Attempt                                        0
# Incorrects                                                 NaN
# Hints                                                      NaN
# Corrects                                                   NaN
# KC(Default)                                   Entering a given
# Opportunity(Default)                                        68
# Name: 1102, dtype: object
# Row                                                    1057803
# Anon Student Id                                     6c2Im3PZdL
# Problem Hierarchy              Unit CTA1_04, Section CTA1_04-4
# Problem Name                                            BH1T47
# Problem View                                                 1
# Step Name                                                 R4C1
# Step Start Time                                            NaN
# First Transaction Time                                     NaN
# Correct Transaction Time                                   NaN
# Step End Time                                              NaN
# Step Duration (sec)                                        NaN
# Correct Step Duration (sec)                                NaN
# Error Step Duration (sec)                                  NaN
# Correct First Attempt                                        0
# Incorrects                                                 NaN
# Hints                                                      NaN
# Corrects                                                   NaN
# KC(Default)                                   Entering a given
# Opportunity(Default)                                        14
# Name: 1108, dtype: object
# Row                                                                      1058336
# Anon Student Id                                                       7o7172ufx2
# Problem Hierarchy                                Unit CTA1_08, Section CTA1_08-3
# Problem Name                                                               JAN12
# Problem View                                                                   1
# Step Name                                                                   R3C2
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                    Using small numbers~~Write expression, negativ...
# Opportunity(Default)                                                    13~~3~~8
# Name: 1111, dtype: object
# Row                                                                      1071411
# Anon Student Id                                                       UEArk7W20r
# Problem Hierarchy                                   Unit ES_05, Section ES_05-10
# Problem Name                                                                EG62
# Problem View                                                                   1
# Step Name                                               -0.790089y+0.1573426 = y
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                    [SkillRule: Consolidate vars, any; {Combine va...
# Opportunity(Default)                                                          22
# Name: 1120, dtype: object
# Row                                                    1071701
# Anon Student Id                                     UEArk7W20r
# Problem Hierarchy              Unit CTA1_14, Section CTA1_14-3
# Problem Name                                           2PTFB12
# Problem View                                                 1
# Step Name                                       60 = (4)(10)+b
# Step Start Time                                            NaN
# First Transaction Time                                     NaN
# Correct Transaction Time                                   NaN
# Step End Time                                              NaN
# Step Duration (sec)                                        NaN
# Correct Step Duration (sec)                                NaN
# Error Step Duration (sec)                                  NaN
# Correct First Attempt                                        0
# Incorrects                                                 NaN
# Hints                                                      NaN
# Corrects                                                   NaN
# KC(Default)                                                NaN
# Opportunity(Default)                                       NaN
# Name: 1121, dtype: object
# Row                                                                      1073863
# Anon Student Id                                                       XGFd357i6u
# Problem Hierarchy                                Unit CTA1_14, Section CTA1_14-3
# Problem Name                                                              2PTS02
# Problem View                                                                   1
# Step Name                                                                   R3C2
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                    Using simple numbers~~Using large numbers~~Wri...
# Opportunity(Default)                                                   66~~44~~4
# Name: 1125, dtype: object
# Row                                                    1074230
# Anon Student Id                                     42FRuGgL06
# Problem Hierarchy              Unit CTA1_08, Section CTA1_08-2
# Problem Name                                           L3_DEMO
# Problem View                                                 1
# Step Name                                    Formula 1 Coeff 1
# Step Start Time                                            NaN
# First Transaction Time                                     NaN
# Correct Transaction Time                                   NaN
# Step End Time                                              NaN
# Step Duration (sec)                                        NaN
# Correct Step Duration (sec)                                NaN
# Error Step Duration (sec)                                  NaN
# Correct First Attempt                                        0
# Incorrects                                                 NaN
# Hints                                                      NaN
# Corrects                                                   NaN
# KC(Default)                                  Setting the slope
# Opportunity(Default)                                         8
# Name: 1128, dtype: object
# Row                                                                      1075052
# Anon Student Id                                                       C0qLCIhI0O
# Problem Hierarchy                                    Unit ES_04, Section ES_04-1
# Problem Name                                                                EG40
# Problem View                                                                   2
# Step Name                                                               10y = -1
# Step Start Time                                                              NaN
# First Transaction Time                                                       NaN
# Correct Transaction Time                                                     NaN
# Step End Time                                                                NaN
# Step Duration (sec)                                                          NaN
# Correct Step Duration (sec)                                                  NaN
# Error Step Duration (sec)                                                    NaN
# Correct First Attempt                                                          0
# Incorrects                                                                   NaN
# Hints                                                                        NaN
# Corrects                                                                     NaN
# KC(Default)                    [SkillRule: Remove positive coefficient; {ax/b...
# Opportunity(Default)                                                        1~~2
# Name: 1132, dtype: object
# Row                                                             1078861
# Anon Student Id                                              JP20cryBg8
# Problem Hierarchy                       Unit CTA1_24, Section CTA1_24-1
# Problem Name                                                      NOV05
# Problem View                                                          1
# Step Name                                                          R7C1
# Step Start Time                                                     NaN
# First Transaction Time                                              NaN
# Correct Transaction Time                                            NaN
# Step End Time                                                       NaN
# Step Duration (sec)                                                 NaN
# Correct Step Duration (sec)                                         NaN
# Error Step Duration (sec)                                           NaN
# Correct First Attempt                                                 0
# Incorrects                                                          NaN
# Hints                                                               NaN
# Corrects                                                            NaN
# KC(Default)                    Entering a given~~Convert unit, standard
# Opportunity(Default)                                              23~~2
# Name: 1139, dtype: object
